# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.arange(-10,10,0.001)
y1=np.sin(x)
y2=np.cos(x)

# %%
plt.plot(x,y1,'g',x,y2,'r')
plt.grid()
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('sine and cosine curve')
# Out:
# Text(0.5, 1.0, 'sine and cosine curve')
