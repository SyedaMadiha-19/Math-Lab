# %% [markdown]
# # learning python
# importing pyplot from matplotlib
# defining 2 data sets x and y

# %%
from matplotlib.pyplot import*
x = [1,2,3,4,5]
y = [6,7,8,9,0]

# %% [markdown]
# Scatter function to plot a graph from x and y data sets

# %%
scatter(x,y)
