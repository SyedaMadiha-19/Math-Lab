# %%
 from matplotlib.pyplot import*

# %%
x = [0,1,2,3,4]
y = [5,6,7,8,9]

# %%
xlabel('x-axis')
ylabel('y-axis')
# Out:
# Text(0, 0.5, 'y-axis')

# %%
title('LINE GRAPH!')
# Out:
# Text(0.5, 1.0, 'LINE GRAPH!')

# %%
plot( x,y,'y*-')
